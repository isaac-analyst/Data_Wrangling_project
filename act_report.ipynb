# %% [markdown]
# ## Report: act_report

# %% [markdown]
# ### Introduction

# %% [markdown]
# WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. In this report i will communicates the insights and displays the visualizations produced from the wrangled data.
# The data has been gathered, cleaned and analysed will form the basis of this report.

# %% [markdown]
# ## Insights and Visualizations

# %% [markdown]
# The analyzed data shows that  **Lucy, Cooper, Charlie** were the most common names of dogs tweeted about.

# %% [markdown]
# From the analysis its that a very strong positive correlations exists between retweet_count and favorite_count with a correlation value of **0.913**. this indicated that most people who read and like the tweets always retweets it.
#
# ![download-2.png](attachment:download.png)

# %% [markdown]
# it was however shows that the dog breeds that has the highest retweet was **golden_retriever** follows by **Labrador_retriever  Pembroke, Chihuahua** and **Samoyed** respectivelly. it indicated that those who retweeted like the dog breed.
#
#
# ![download-2.png](attachment:download-2.png)

# %% [markdown]
# the analysis shows that the most common breed tweeted about was golden_retriever and Labrador_retriever.
# the analysis also indicated that most of the tweet sources came from  **twitter for iphone**. which indicate that most of the people that tweeted uses iphone to tweet.

# %% [markdown]
# The data also shows that **pupper** was the most categories of dog tweeted about, this indicated the popularity of the dogs among the those that tweeted. this may be as a result of the cuteness of the dog.

# %% [markdown]
# the analysis also shows that golden_retriever was the dog breed that has the most favorite tweet count, this can be attributed to the fact that people love and like the dog which will mostly prompt them to always likely retweet the dog breeds.
#
#
# ![download.png](attachment:download.png)
